# %% [markdown]
# # **Paraphrasing of Sentance**

# %% [markdown]
# ### **Import dependency**

# %%
# Import git library Parrot_Paraphraser
# !pip install git+https://github.com/PrithivirajDamodaran/Parrot_Paraphraser.git
# Out:
# ...
#   Cloning https://github.com/PrithivirajDamodaran/Parrot_Paraphraser.git to /tmp/pip-req-build-xh0roqaq
#   Running command git clone --filter=blob:none --quiet https://github.com/PrithivirajDamodaran/Parrot_Paraphraser.git /tmp/pip-req-build-xh0roqaq
#   Resolved https://github.com/PrithivirajDamodaran/Parrot_Paraphraser.git to commit 03084c54b64019ba5fa0b620b9c70ad81123e458
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 53.8 MB/s eta 0:00:00
# ...
#   Created wheel for parrot: filename=parrot-1.0-py3-none-any.whl size=8589 sha256=2fb35fd4fc78ddc9897f6c5a05f68e8f2c52e4388d049b670f92ddefa013e167
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ls2mk3y1/wheels/e8/ee/2a/4d6a4b2a5c37f5f750e90fa79d2ad84f444fba9b050ecbbe6d
# Successfully built parrot
# ...

# %%
# Import dependency
from parrot import Parrot
import torch
import warnings
warnings.filterwarnings("ignore")

# %%
parrot = Parrot(model_tag="prithivida/parrot_paraphraser_on_T5", use_gpu=False)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.89k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.37k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/913 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# ...

# %%
phrases = ['Which school is best for icse in India']

# %%
for phrase in phrases:
  print("-"*100)
  print("Input_phrase: ", phrase)
  print("-"*100)
  para_phrases = parrot.augment(input_phrase=phrase, do_diverse= False)
  for para_phrase in para_phrases:
   print(para_phrase)
# Out:
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  Which school is best for icse in India
# ----------------------------------------------------------------------------------------------------
# ('which is the best icse school in india?', 31)
# ('which is the best school for icse in india?', 25)
# ('which school is best for icse in india?', 13)

# %%
para_phrases = parrot.augment(input_phrase=phrase,
                               diversity_ranker="levenshtein",
                               do_diverse=True,
                               max_return_phrases = 10,
                               max_length=32,
                               adequacy_threshold = 0.2,
                               fluency_threshold = 0.30)

# %%
para_phrases
# Out:
# [('which is the best icse school in india?', 31),
#  ('which is the best school for ices in india?', 27),
#  ('which is the best school for icse in india?', 25),
#  ('is there any good school for icse in india?', 25),
#  ('is there a good school for icse in india?', 24),
#  ('which school is the best for icse in india?', 17),
#  ('which school is best for icse in india?', 13)]

# %% [markdown]
#  **Another example Paraphrasing of Sentance**

# %%
phrases=['show me nearest HDFC banks']

# %%
for phrase in phrases:
  print("-"*100)
  print("Input_phrase: ", phrase)
  print("-"*100)
  para_phrases = parrot.augment(input_phrase=phrase, do_diverse= False)
  for para_phrase in para_phrases:
   print(para_phrase)
# Out:
# ----------------------------------------------------------------------------------------------------
# Input_phrase:  show me nearest HDFC banks
# ----------------------------------------------------------------------------------------------------
# ('show me the closest hdfc banks', 19)
# ('show me the nearest hdfc banks', 15)
# ('please show me the nearest hdfc bank', 12)

# %%
para_phrases = parrot.augment(input_phrase=phrase,
                               diversity_ranker="levenshtein",
                               do_diverse=True,
                               max_return_phrases = 10,
                               max_length=32,
                               adequacy_threshold = 0.2,
                               fluency_threshold = 0.30)

# %%
para_phrases
# Out:
# [('show me the closest hdfc banks', 19),
#  ('show the closest hdfc bank', 19),
#  ('show the closest hdfc banks', 18),
#  ('can you list the nearest hdfc banks', 16),
#  ('show me the nearest hdfc banks', 15),
#  ('show the nearest hdfc bank', 15),
#  ('show the nearest hdfc banks', 14),
#  ('please show the closest hdfc banks', 13),
#  ('please show the nearest hdfc banks', 9)]
